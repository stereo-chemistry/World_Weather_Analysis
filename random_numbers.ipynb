# %%
import random

# %%
import numpy as np

# %%
import timeit

# %%
random.randint(-90, 90)
# Out:
# 65

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 65.9935823945565

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
latitudes
# Out:
# [-29.684996558207416,
#  77.87376127593288,
#  -58.71670628382041,
#  -66.40785811094872,
#  -54.6726005743905,
#  -51.64000794506898,
#  -68.01410125443911,
#  58.54798230372247,
#  2.8704393430760717,
#  40.54556096347874]

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -21.5069017918905

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 89.00794680277693

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 23.7330465 ,  43.04761567,  71.50083162,  25.04833896,
#        -71.39272828, -52.54770624,  76.68155816, -68.46935219,
#        -14.61798599, -17.84207429, -36.12680188,  55.39680937,
#        -78.53852474,  -5.75321118,  38.87395484, -60.39188287,
#        -66.65512971, -16.89171507, -75.49865134, -56.77756955,
#          4.63938484,  54.16203487, -30.10261527,  75.60707394,
#         77.70323812,  41.09119559,  -0.31839103,  15.26918441,
#        -67.36062001,  19.74571023,  29.13158157, -48.39683783,
#         25.01544604,  77.80925242,  -6.65525907,  33.18243257,
#          9.08284279, -22.21076237,   0.12132239,  37.77842546,
#         17.19145853, -20.5501243 , -38.49120071, -46.79693824,
#        -27.99764196, -39.84310571, -20.42072909,  28.96107061,
#         48.7403531 ,  86.82281622])

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 15 µs ± 213 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat - random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# %timeit latitudes(1500)
# Out:
# 2.51 ms ± 35.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
